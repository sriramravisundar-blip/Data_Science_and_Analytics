# %% [markdown]
# <a href="https://colab.research.google.com/github/Vigneshganesh-cse/Data-science-and-analytics/blob/main/intership.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

number = random.randint(1, 100)
attempts = 5

print("Welcome to the Number Guessing Game!")
print("I have chosen a number between 1 and 100.")
print("You have", attempts, "attempts to guess it.")

for i in range(attempts):
    guess = int(input("Enter your guess: "))

    if guess == number:
        print("Congratulations! You guessed the correct number.")
        break
    elif guess < number:
        print("Too low! Try again.")
    else:
        print("Too high! Try again.")

    print("Attempts left:", attempts - i - 1)

if guess != number:
    print("Sorry! You have used all your attempts.")
    print("The correct number was", number)
# Out:
# Welcome to the Number Guessing Game!
# I have chosen a number between 1 and 100.
# You have 5 attempts to guess it.
# Enter your guess: 76
# Too high! Try again.
# Attempts left: 4
# Enter your guess: 44
# Too high! Try again.
# Attempts left: 3
# Enter your guess: 34
# Congratulations! You guessed the correct number.
